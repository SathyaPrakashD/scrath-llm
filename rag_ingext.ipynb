# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from rag_helper import RAGBase
#       2 from ingest import load_faq_data, build_index
#
# ImportError: cannot import name 'RAGBase' from 'rag_helper' (/workspaces/scrath-llm/rag_helper.py)

# %%
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
openai_client = OpenAI()

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index, openai_client)

# %%
assistant.rag('I just discovered the course, can I still join?')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 assistant.rag('I just discovered the course, can I still join?')
#
# File /workspaces/scrath-llm/rag_helper.py:73, in RAGBase.rag(self, query)
#      72 def rag(self, query):
# ---> 73     search_results = self.search(query)
#      74     prompt = self.build_prompt(query, search_results)
#      75     answer = self.llm(prompt)
#
# AttributeError: 'RAGHelper' object has no attribute 'search'
